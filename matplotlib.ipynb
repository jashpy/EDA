# %% [markdown]
# __problem-1__

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# matplotlib is a library which is used to plot diagrams for visualisation.
#
# 1.scatterplot:
# relationship between two variables
#
# 2.barplot:
# just to visualize y vs x
#
# 3.boxplot:
# used to visualize for feature selection
#
# 4.pieplot:
# used to visualise as a composition
#
# 5.contourplot:
# used to visualize in 3d(x,y,z)

# %% [markdown]
# __problem-2__

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y,c='green')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
plt.title("SCATTERPLOT")
plt.show()

# %% [markdown]
# __problem-3__

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
#with the help of subplot() we can make multiple plots in one plot

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4= np.array([200, 350, 250, 550, 450, 150])

fig, ax = plt.subplots(nrows=2, ncols=2)
ax[0,0].plot(x1, y1,c='green')
ax[0,1].plot(x2, y2,c='yellow')
ax[1,0].plot(x3, y3,c='red')
ax[1,1].plot(x4, y4,c='blue')

ax[0,0].set_title('LINE-1')
ax[0,1].set_title('LINE-2')
ax[1,0].set_title('LINE-3')
ax[1,1].set_title('LINE-4')


fig.suptitle('SUBPLOTS')
plt.show()

# %% [markdown]
# __problem-4__

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
#barplot is type of graph used to visualise y vs x

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
plt.xlabel("COMPANIES")
plt.ylabel("PROFIT")
plt.title("VERTICAL BAR PLOT")
plt.grid()
plt.show()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.barh(company,profit)
plt.xlabel("COMPANIES")
plt.ylabel("PROFIT")
plt.title("HORIZONTAL BAR PLOT")
plt.grid()
plt.show()

# %% [markdown]
# __problem-5__

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
#box plot is a tool by means of which we can judge the ouliers and we can apply the statistical knowledge as well

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

boxes=[box1,box2]
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(boxes)
plt.show()
